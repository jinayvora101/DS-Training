# %%
# Questions:

# 1. In XYZ hospital, the healthcare professional selection process has a rejection rate of 10%. Based on their qualifications and experience
# a random selection is done out of 5 candidates. Assume that in a random selection process, in each round candidates are rejected.
# What is the probability of rejecting 1 candidate in a single round?

# 2. In an e-commerce store, the marketing team has observed that the probability of a purchase by any customer is 10%.
# Determine the probability of the 100th purchase occurring with the 20th customer.

# 3. A call centre manager has detemined that the probability of a successful call is 15%. Find the probability of the occurance
# of the first successful call at 5th call?

# 4. A retail store observed that the average number of customers entering the store is 5 per hour.
# What is the probability of 10 customer arrivals within the next hour?

# 5. A Bank wants to evaluates the performance of its employees using a rating scale.
# The ratings follow a normal distribution with a mean of 3.5 and a standard deviation of 0.8.
# If a random employee is selected, what is the probability that their performance rating is greater than 4.2?

# %%
5*0.1*0.9**4
# Out:
# 0.32805

# %%
from scipy.stats import nbinom

nbinom.pmf(80, 20, 0.1)
# Out:
# 0.0002341973982809932

# %%
from scipy.stats import geom

nbinom.pmf(4, 1, 0.15)
# Out:
# 0.07830093750000003

# %%
from scipy.stats import poisson

poisson.cdf(10, 5)
# Out:
# 0.9863047314016171

# %%
from scipy.stats import norm

1 - norm.cdf(4.2, 3.5, 0.8)
# Out:
# 0.19078695285251057
