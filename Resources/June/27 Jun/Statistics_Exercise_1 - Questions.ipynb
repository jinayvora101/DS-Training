# %%
# Questions:

# 1. Define a function for computing median without using any python library, and use the same to locate the median of the
# following data: [2,0,1,2,5,6]
# 2. Read the Car_data and calculate the relevant measures of central tendency for the price column
# 3. Read the Sales_data and compute the variance and standard deviation. Also, determine the least consistent sales person.
# 4. Determine the probability of choosing a car with rating 'A' from the Car_data
# 5. What is the modal value of car type?

# %%
import numpy as np
import pandas as pd
from statistics import mode

# %%
## 1.

x = np.array([2,0,1,2,5,6])
np.median(x)
# Out:
# 2.0

# %%
## 2

df = pd.read_excel("Car_data.xlsx")
df["Price"].mean(), df["Price"].median(), mode(df["Price"])
# Out:
# (17009.8, 16980.0, 27000)

# %%
## 3.

df = pd.read_excel("Sales_data.xlsx")

[df["SP1"].var(), df["SP1"].std()], [df["SP2"].var(), df["SP2"].std()], [df["SP3"].var(), df["SP3"].std()]
# Out:
# ([12999800000.0, 114016.66544852116],
#  [62300000.0, 7893.034904268447],
#  [6442300000.0, 80263.93959929951])

# %%
## 4.

df = pd.read_excel("Car_data.xlsx")
df["Rating"].value_counts(normalize=True).loc["A"]
# Out:
# 0.2

# %%
## 5.

df = pd.read_excel("Car_data.xlsx")
mode(df["Rating"].values)
# Out:
# 'B'
