# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Survived"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Survived'>

# %%
df.groupby("Pclass").agg({"Fare": np.mean})
# Out:
#              Fare
# Pclass
# 1       84.154687
# 2       20.662183
# 3       13.675550

# %%
df.query(""" Embarked == "C" """).count()
# Out:
# PassengerId    168
# Survived       168
# Pclass         168
# Name           168
# Sex            168
# Age            130
# SibSp          168
# Parch          168
# Ticket         168
# Fare           168
# Cabin           69
# Embarked       168
# dtype: int64

# %%
df["Fare"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.query(""" Survived == 1 """)["Age"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.query(""" Survived == 0 """)["Age"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[["Sex", "Survived"]].value_counts().plot(kind="bar", stacked=True)
# Out:
# <AxesSubplot:xlabel='Sex,Survived'>

# %%
df.query(""" SibSp >= 4 """).sort_values(by="Fare", ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 863          864         0       3        Sage, Miss. Dorothy Edith "Dolly"
# 159          160         0       3               Sage, Master. Thomas Henry
# 324          325         0       3                 Sage, Mr. George John Jr
# 201          202         0       3                      Sage, Mr. Frederick
# 180          181         0       3             Sage, Miss. Constance Gladys
# 846          847         0       3                 Sage, Mr. Douglas Bullen
# 792          793         0       3                  Sage, Miss. Stella Anna
# 59            60         0       3       Goodwin, Master. William Frederick
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# 683          684         0       3              Goodwin, Mr. Charles Edward
# 480          481         0       3           Goodwin, Master. Harold Victor
# ...

# %%
df.plot(x="Age", y="Fare", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
df.corr(method="pearson").round(4)*100
# Out:
#              PassengerId  Survived  Pclass     Age   SibSp   Parch    Fare
# PassengerId       100.00     -0.50   -3.51    3.68   -5.75   -0.17    1.27
# Survived           -0.50    100.00  -33.85   -7.72   -3.53    8.16   25.73
# Pclass             -3.51    -33.85  100.00  -36.92    8.31    1.84  -54.95
# Age                 3.68     -7.72  -36.92  100.00  -30.82  -18.91    9.61
# SibSp              -5.75     -3.53    8.31  -30.82  100.00   41.48   15.97
# Parch              -0.17      8.16    1.84  -18.91   41.48  100.00   21.62
# Fare                1.27     25.73  -54.95    9.61   15.97   21.62  100.00

# %%
pd.pivot_table(data=df, index="Sex", columns="Embarked", values="Survived", aggfunc="count")
# Out:
# Embarked   C   Q    S
# Sex
# female    73  36  203
# male      95  41  441

# %%
df.query(""" Survived == 0 """).pivot_table(index="Sex", columns="Embarked", values="Survived", aggfunc="count")
# Out:
# Embarked   C   Q    S
# Sex
# female     9   9   63
# male      66  38  364
